# %%
# %matplotlib notebook

# %%
# Dependencies
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %%
salary_data = pd.read_csv("salary.csv")
salary_data.head()
# Out:
#            County State Long  Annual Establishments  \
# 0  Autauga County    Alabama                    871
# 1  Baldwin County    Alabama                   6298
# 2  Barbour County    Alabama                    555
# 3     Bibb County    Alabama                    374
# 4   Blount County    Alabama                    780
#
#    Annual Average Employment  Total Annual Wages  Annual Average Weekly Wage  \
# 0                      10954        4.206958e+08                         739
# 1                      74017        2.723207e+09                         708
# 2                       8114        3.098525e+08                         734
# 3                       4216        1.689600e+08                         771
# 4                       8527        3.035764e+08                         685
#
#    Annual Wages per Employee  Annual Average Employment Location Quotient  \
# 0                      38405                                            1
# ...

# %%
salary_data_df = salary_data.
